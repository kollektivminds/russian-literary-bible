# %% [markdown]
# # Synodal Bible & Mother

# %% [markdown]
# ## Summary

# %%
# Code summary of below

# %%
# !python --version
# Out:
# Python 3.11.4

# %% [markdown]
# ## Import

# %% [markdown]
# ### Libraries

# %%
from backend import *
import multiprocessing as mp
from multiprocessing import Pool, Process
import pickle
num_cores = int(mp.cpu_count()-2)
print(f"Number of cores : {num_cores}")
# Out:
# Number of cores : 38

# %%
#%matplotlib inline

# %% [markdown]
# ### Definitions

# %%
texts = '../texts/fiction/utf8/'

libCols = ['author','pub_year','title','text']
tokenOHCO = ['w_id','part_num','para_num', 'sent_num', 'token_num']
tokenCols = ['p_id', 'start', 'stop', 'text', 'token_id', 'head_id', 'rel', 'pos', 'lemma', 'anim', 'aspect', \
             'case', 'degree', 'gender', 'mood', 'number', 'person', 'tense', 'verb_form', 'voice']

# %%
motherTokenDf = pd.read_pickle('./proc/MotherTokendf.pkl')
bibleTokenDf = pd.read_pickle('./proc/BibleTokenDf.pkl')
confessionTokenDf = pd.read_pickle('./proc/ConfessionTokenDf.pkl')

# %%
good_pos = ['NOUN', 'ADJ', 'VERB', 'PROPN']

# %% [raw]
# # add stopword boolean, True if all attribute columns are null
# #motherTokenDf['stopword'] = ~motherTokenDf.loc[:, tokenCols[9:]].any(axis=1)
# motherTokenDf['stopword'] = ~motherTokenDf.pos.isin(good_pos)
# TokenDfIdx = pd.Index(range(1, (motherTokenDf.shape[0]+1)), name='id')
# motherTokenDf.index = TokenDfIdx# = TokenDf.set_index(['p_id', 'token_id'])
#
# bibleTokenDf['stopword'] = ~bibleTokenDf.pos.isin(good_pos)
# TokenDfIdx = pd.Index(range(1, (bibleTokenDf.shape[0]+1)), name='id')
# bibleTokenDf.index = TokenDfIdx# = TokenDf.set_index(['p_id', 'token_id'])
#
# confessionTokenDf['stopword'] = ~confessionTokenDf.pos.isin(good_pos)
# TokenDfIdx = pd.Index(range(1, (confessionTokenDf.shape[0]+1)), name='id')
# confessionTokenDf.index = TokenDfIdx# = TokenDf.set_index(['p_id', 'token_id'])

# %%
# add stopword boolean, True if all attribute columns are null
motherTokenDf = add_stopword(motherTokenDf)
bibleTokenDf = add_stopword(bibleTokenDf)
confessionTokenDf = add_stopword(confessionTokenDf)

# %% [markdown]
# ## Bible and Mother Token Dataframes

# %%
bibleTokenDf
# Out:
#          p_id start stop      text token_id head_id        rel    pos  \
# id
# 1           1     0    1         В      1_1     1_2       case    ADP
# 2           1     2    8    начале      1_2     1_3        obl   NOUN
# 3           1     9   17  сотворил      1_3     1_0       root   VERB
# 4           1    18   21       Бог      1_4     1_3      nsubj  PROPN
# 5           1    22   26      небо      1_5     1_3        obj   NOUN
# ...       ...   ...  ...       ...      ...     ...        ...    ...
# 675064  37086    32   38    Христа      1_5     1_4  flat:name  PROPN
# 675065  37086    39   41        со      1_6     1_8       case    ADP
# 675066  37086    42   47     всеми      1_7     1_8        det    DET
# 675067  37086    48   52      вами      1_8     1_4       nmod   PRON
# 675068  37086    54   59     Аминь      2_1     2_0       root  PROPN
#
#             lemma  anim  ...  case degree gender  mood number person tense  \
# id                       ...
# 1               в  None  ...  None   None   None  None   None   None  None
# 2          начало  Inan  ...   Loc   None   Neut  None   Sing   None  None
# 3       сотворить  None  ...  None   None   Masc   Ind   Sing   None  Past
# 4             бог  Anim  ...   Nom   None   Masc  None   Sing   None  None
# 5            небо  Inan  ...   Acc   None   Neut  None   Sing   None  None
# ...           ...   ...  ...   ...    ...    ...   ...    ...    ...   ...
# 675064    христос  Anim  ...   Gen   None   Masc  None   Sing   None  None
# 675065          с  None  ...  None   None   None  None   None   None  None
# 675066       весь  None  ...   Ins   None   None  None   Plur   None  None
# 675067         вы  None  ...   Ins   None   None  None   Plur      2  None
# 675068      аминь  Inan  ...   Gen   None    Fem  None   Sing   None  None
#
#        verb_form voice stopword
# id
# 1           None  None     True
# 2           None  None    False
# 3            Fin   Act    False
# 4           None  None    False
# 5           None  None    False
# ...          ...   ...      ...
# 675064      None  None    False
# 675065      None  None     True
# 675066      None  None     True
# 675067      None  None     True
# 675068      None  None    False
#
# [675068 rows x 21 columns]

# %%
bibleTokenDf.loc[bibleTokenDf.stopword == False]
# Out:
#          p_id start stop       text token_id head_id        rel    pos  \
# id
# 2           1     2    8     начале      1_2     1_3        obl   NOUN
# 3           1     9   17   сотворил      1_3     1_0       root   VERB
# 4           1    18   21        Бог      1_4     1_3      nsubj  PROPN
# 5           1    22   26       небо      1_5     1_3        obj   NOUN
# 7           1    29   34      землю      1_7     1_5       conj   NOUN
# ...       ...   ...  ...        ...      ...     ...        ...    ...
# 675060  37086     0    9  Благодать      1_1     1_2      nsubj   NOUN
# 675061  37086    10   17    Господа      1_2     1_1      appos  PROPN
# 675063  37086    25   31     Иисуса      1_4     1_1       nmod  PROPN
# 675064  37086    32   38     Христа      1_5     1_4  flat:name  PROPN
# 675068  37086    54   59      Аминь      2_1     2_0       root  PROPN
#
#             lemma  anim  ...  case degree gender  mood number person tense  \
# id                       ...
# 2          начало  Inan  ...   Loc   None   Neut  None   Sing   None  None
# 3       сотворить  None  ...  None   None   Masc   Ind   Sing   None  Past
# 4             бог  Anim  ...   Nom   None   Masc  None   Sing   None  None
# 5            небо  Inan  ...   Acc   None   Neut  None   Sing   None  None
# 7           земля  Inan  ...   Acc   None    Fem  None   Sing   None  None
# ...           ...   ...  ...   ...    ...    ...   ...    ...    ...   ...
# 675060  благодать  Inan  ...   Nom   None    Fem  None   Sing   None  None
# 675061    господь  Anim  ...   Gen   None   Masc  None   Sing   None  None
# 675063      иисус  Anim  ...   Gen   None   Masc  None   Sing   None  None
# 675064    христос  Anim  ...   Gen   None   Masc  None   Sing   None  None
# 675068      аминь  Inan  ...   Gen   None    Fem  None   Sing   None  None
#
#        verb_form voice stopword
# id
# 2           None  None    False
# 3            Fin   Act    False
# 4           None  None    False
# 5           None  None    False
# 7           None  None    False
# ...          ...   ...      ...
# 675060      None  None    False
# 675061      None  None    False
# 675063      None  None    False
# 675064      None  None    False
# 675068      None  None    False
#
# [345090 rows x 21 columns]

# %%
motherTokenDf#.set_index(['p_id','token_id'])
# Out:
#        p_id start stop       text token_id head_id    rel   pos     lemma  \
# id
# 1         1     7   13     Каждый      1_1     1_2    det   DET    каждый
# 2         1    14   18       день      1_2    1_28    obl  NOUN      день
# 3         1    19   22        над      1_3     1_5   case   ADP       над
# 4         1    23   30    рабочей      1_4     1_5   amod   ADJ   рабочий
# 5         1    31   40  слободкой      1_5    1_28    obl  NOUN  слободка
# ...     ...   ...  ...        ...      ...     ...    ...   ...       ...
# 86005  4436     7   13     Кто-то      1_1     1_2  nsubj  PRON    кто-то
# 86006  4436    14   21    ответил      1_2     1_0   root  VERB  ответить
# 86007  4436    22   24         ей      1_3     1_2   iobj  PRON       она
# 86008  4436    25   32    громким      1_4     1_5   amod   ADJ   громкий
# 86009  4436    33   41   рыданием      1_5     1_2    obl  NOUN   рыдание
#
#        anim  ...  case degree gender  mood number person tense verb_form  \
# id           ...
# 1      None  ...   Acc   None   Masc  None   Sing   None  None      None
# 2      Inan  ...   Acc   None   Masc  None   Sing   None  None      None
# 3      None  ...  None   None   None  None   None   None  None      None
# 4      None  ...   Ins    Pos    Fem  None   Sing   None  None      None
# 5      Inan  ...   Ins   None    Fem  None   Sing   None  None      None
# ...     ...  ...   ...    ...    ...   ...    ...    ...   ...       ...
# 86005  None  ...   Nom   None   None  None   None   None  None      None
# 86006  None  ...  None   None   Masc   Ind   Sing   None  Past       Fin
# 86007  None  ...   Dat   None    Fem  None   Sing      3  None      None
# 86008  None  ...   Dat    Pos   None  None   Plur   None  None      None
# 86009  Anim  ...   Dat   None   Masc  None   Plur   None  None      None
#
#       voice stopword
# id
# 1      None     True
# 2      None    False
# 3      None     True
# 4      None    False
# 5      None    False
# ...     ...      ...
# 86005  None     True
# 86006   Act    False
# 86007  None     True
# 86008  None    False
# 86009  None    False
#
# [86009 rows x 21 columns]

# %%
motherTokenDf.loc[motherTokenDf.stopword == False]
# Out:
#        p_id start stop        text token_id head_id   rel   pos       lemma  \
# id
# 2         1    14   18        день      1_2    1_28   obl  NOUN        день
# 4         1    23   30     рабочей      1_4     1_5  amod   ADJ     рабочий
# 5         1    31   40   слободкой      1_5    1_28   obl  NOUN    слободка
# 7         1    44   50      дымном      1_8    1_34  conj  NOUN      дымный
# 8         1    52   60    масляном     1_10    1_11  amod  VERB    масляный
# ...     ...   ...  ...         ...      ...     ...   ...   ...         ...
# 86003  4434    54   61     хрипела      2_2     2_0  root   ADJ     хрипеть
# 86004  4435    10   20  Несчастные      1_2     1_0  root   ADJ  несчастный
# 86006  4436    14   21     ответил      1_2     1_0  root  VERB    ответить
# 86008  4436    25   32     громким      1_4     1_5  amod   ADJ     громкий
# 86009  4436    33   41    рыданием      1_5     1_2   obl  NOUN     рыдание
#
#        anim  ...  case degree gender  mood number person tense verb_form  \
# id           ...
# 2      Inan  ...   Acc   None   Masc  None   Sing   None  None      None
# 4      None  ...   Ins    Pos    Fem  None   Sing   None  None      None
# 5      Inan  ...   Ins   None    Fem  None   Sing   None  None      None
# 7      Inan  ...   Loc   None   Masc  None   Sing   None  None      None
# 8      None  ...   Loc   None   Masc  None   Sing   None  Pres      Part
# ...     ...  ...   ...    ...    ...   ...    ...    ...   ...       ...
# 86003  None  ...  None    Pos    Fem  None   Sing   None  None      None
# 86004  None  ...   Nom    Pos   None  None   Plur   None  None      None
# 86006  None  ...  None   None   Masc   Ind   Sing   None  Past       Fin
# 86008  None  ...   Dat    Pos   None  None   Plur   None  None      None
# 86009  Anim  ...   Dat   None   Masc  None   Plur   None  None      None
#
#       voice stopword
# id
# 2      None    False
# 4      None    False
# 5      None    False
# 7      None    False
# 8       Act    False
# ...     ...      ...
# 86003  None    False
# 86004  None    False
# 86006   Act    False
# 86008  None    False
# 86009  None    False
#
# [46836 rows x 21 columns]

# %%
confessionTokenDf
# Out:
#        p_id start stop               text token_id head_id     rel   pos  \
# id
# 1         1    10   19          Позвольте      1_2     1_0    root  VERB
# 2         1    20   30         рассказать      1_3     1_2   xcomp  VERB
# 3         1    31   36              жизнь      1_4     1_3     obj  NOUN
# 4         1    37   40                мою      1_5    1_17     det   DET
# 5         1    42   49            времени      1_7    1_10     obj  NOUN
# ...     ...   ...  ...                ...      ...     ...     ...   ...
# 47480  2360   283  291           великого     1_49    1_50    amod   ADJ
# 47481  2360   292  296               дела     1_50    1_11     obl  NOUN
# 47482  2360   300  310         всемирного     1_52    1_53    amod   ADJ
# 47483  2360   311  328  богостроительства     1_53    1_50   appos  NOUN
# 47484  2360   329  333               ради     1_54    1_11  advmod  NOUN
#
#                    lemma  anim  ...  case degree gender  mood number person  \
# id                              ...
# 1              позволить  None  ...  None   None   None   Imp   Plur      2
# 2             рассказать  None  ...  None   None   None  None   None   None
# 3                  жизнь  Inan  ...   Acc   None    Fem  None   Sing   None
# 4                    мой  None  ...   Acc   None    Fem  None   Sing   None
# 5                  время  Inan  ...   Gen   None   Neut  None   Sing   None
# ...                  ...   ...  ...   ...    ...    ...   ...    ...    ...
# 47480            великий  None  ...   Gen    Pos   Neut  None   Sing   None
# 47481               дело  Inan  ...   Gen   None   Neut  None   Sing   None
# 47482          всемирный  None  ...   Gen    Pos   Masc  None   Sing   None
# 47483  богостроительство  Inan  ...   Gen   None   Neut  None   Sing   None
# 47484               ради  Inan  ...   Gen   None   Masc  None   Sing   None
#
#       tense verb_form voice stopword
# id
# 1      None       Fin   Act    False
# 2      None       Inf   Act    False
# 3      None      None  None    False
# 4      None      None  None     True
# 5      None      None  None    False
# ...     ...       ...   ...      ...
# 47480  None      None  None    False
# 47481  None      None  None    False
# 47482  None      None  None    False
# 47483  None      None  None    False
# 47484  None      None  None    False
#
# [47484 rows x 21 columns]

# %%
lemmaDf = bibleTokenDf[['lemma']].loc[bibleTokenDf.stopword == False].join(motherTokenDf[['lemma']].loc[motherTokenDf.stopword == False], on='id', lsuffix='_bible', rsuffix='_mother')
lemmaDf
# Out:
#        lemma_bible lemma_mother
# id
# 2           начало         день
# 3        сотворить          NaN
# 4              бог      рабочий
# 5             небо     слободка
# 7            земля       дымный
# ...            ...          ...
# 675060   благодать          NaN
# 675061     господь          NaN
# 675063       иисус          NaN
# 675064     христос          NaN
# 675068       аминь          NaN
#
# [345090 rows x 2 columns]

# %% [markdown]
# ## Shared Lemmas

# %%
bible_lemmas = bibleTokenDf.loc[bibleTokenDf.stopword == False].lemma
mother_lemmas = motherTokenDf.loc[motherTokenDf.stopword == False].lemma
confession_lemmas = confessionTokenDf.loc[confessionTokenDf.stopword == False].lemma

# %%
common_lemmas(bible_lemmas, mother_lemmas)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 common_lemmas(bible_lemmas, mother_lemmas)
#
# File /sfs/weka/scratch/amt3ad/projects/diss/codebase/backend.py:274, in common_lemmas(parent, child)
#     271 for lemma in set(child):
#     272     #print(lemma)
#     273     if lemma in parent.unique():
# --> 274         common_lemmas.append(lemma)
#     275         common_lemmas_count += 1
#     276     else:
#
# AttributeError: 'function' object has no attribute 'append'

# %%
common_lemmas(bible_lemmas, confession_lemmas)

# %%
common_lemmas = []
common_lemmas_count = 0

for lemma in set(mother_lemmas):
    #print(lemma)
    if lemma in bible_lemmas.unique():
        common_lemmas.append(lemma)
        common_lemmas_count += 1

print(f"Shared unique words between Mother and the Bible: "+str(common_lemmas_count)+
      ", that's ~"+str(round(((common_lemmas_count/len(set(mother_lemmas)))*100),2))+"%")

# %%
common_lemmas = []
common_lemmas_count = 0

for lemma in set(confession_lemmas):
    #print(lemma)
    if lemma in bible_lemmas.unique():
        common_lemmas.append(lemma)
        common_lemmas_count += 1

print(f"Shared unique words between Confession and the Bible: "+str(common_lemmas_count)+
      ", that's ~"+str(round(((common_lemmas_count/len(set(confession_lemmas)))*100),2))+"%")

# %%
len(set(confession_lemmas))/47484
# Out:
# 0.1261266953078932

# %%
bible_vc = bible_lemmas.to_frame().value_counts().to_frame()
mother_vc = mother_lemmas.to_frame().value_counts().to_frame()
confession_vc = confession_lemmas.to_frame().value_counts().to_frame()

# %%
bible_vc.reset_index().loc[bible_vc.reset_index().lemma == 'мать']
# Out:
#     lemma  count
# 137  мать    366

# %%
mother_vc.reset_index().loc[mother_vc.reset_index().lemma == 'отец']
# Out:
#     lemma  count
# 229  отец     34

# %%
confession_vc.reset_index().loc[confession_vc.reset_index().lemma == 'город']
# Out:
#      lemma  count
# 184  город     21

# %%
countDf = mother_vc.join(bible_vc, lsuffix='_mother', rsuffix='_bible')
countDf = countDf.join(confession_vc, lsuffix='_mother', rsuffix='_confession')
countDf = countDf.rename({'count':'count_confession'}, axis=1)

# %%
motherLemmaDf = countDf[:25].fillna(0).astype(int, errors='ignore')[['count_mother', 'count_bible']].style.background_gradient(cmap='plasma')
confessionLemmaDf = countDf.sort_values('count_confession', ascending=False)[:25].fillna(0).astype(int, errors='ignore')[['count_confession', 'count_bible']].style.background_gradient(cmap='plasma')
bibleLemmaDf = countDf.sort_values('count_bible', ascending=False)[:25].fillna(0).astype(int, errors='ignore').style.background_gradient(cmap='plasma')

# %%
display_side_by_side(motherLemmaDf, bibleLemmaDf, confessionLemmaDf)
# Out:
# <div style="display:flex;"><style type="text/css">
# #T_6bf1b_row0_col0, #T_6bf1b_row1_col1 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_6bf1b_row0_col1, #T_6bf1b_row10_col1, #T_6bf1b_row12_col0 {
#   background-color: #310597;
#   color: #f1f1f1;
# }
# #T_6bf1b_row1_col0 {
#   background-color: #e97158;
#   color: #f1f1f1;
# }
# #T_6bf1b_row2_col0 {
#   background-color: #e56b5d;
#   color: #f1f1f1;
# }
# #T_6bf1b_row2_col1 {
#   background-color: #b12a90;
#   color: #f1f1f1;
# }
# #T_6bf1b_row3_col0 {
#   background-color: #c8437b;
#   color: #f1f1f1;
# }
# #T_6bf1b_row3_col1 {
#   background-color: #e87059;
#   color: #f1f1f1;
# }
# #T_6bf1b_row4_col0 {
#   background-color: #a82296;
#   color: #f1f1f1;
# }
# #T_6bf1b_row4_col1 {
#   background-color: #9814a0;
#   color: #f1f1f1;
# }
# #T_6bf1b_row5_col0, #T_6bf1b_row6_col0 {
#   background-color: #8d0ba5;
#   color: #f1f1f1;
# }
# #T_6bf1b_row5_col1 {
#   background-color: #1d068e;
#   color: #f1f1f1;
# }
# #T_6bf1b_row6_col1, #T_6bf1b_row10_col0, #T_6bf1b_row14_col1 {
#   background-color: #3f049c;
#   color: #f1f1f1;
# }
# #T_6bf1b_row7_col0, #T_6bf1b_row15_col1 {
#   background-color: #8606a6;
#   color: #f1f1f1;
# }
# #T_6bf1b_row7_col1 {
#   background-color: #48039f;
#   color: #f1f1f1;
# }
# #T_6bf1b_row8_col0 {
#   background-color: #7a02a8;
#   color: #f1f1f1;
# }
# #T_6bf1b_row8_col1 {
#   background-color: #350498;
#   color: #f1f1f1;
# }
# #T_6bf1b_row9_col0 {
#   background-color: #41049d;
#   color: #f1f1f1;
# }
# #T_6bf1b_row9_col1, #T_6bf1b_row18_col0 {
#   background-color: #20068f;
#   color: #f1f1f1;
# }
# #T_6bf1b_row11_col0 {
#   background-color: #38049a;
#   color: #f1f1f1;
# }
# #T_6bf1b_row11_col1, #T_6bf1b_row20_col1, #T_6bf1b_row24_col0 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_6bf1b_row12_col1, #T_6bf1b_row13_col1 {
#   background-color: #5b01a5;
#   color: #f1f1f1;
# }
# #T_6bf1b_row13_col0 {
#   background-color: #2e0595;
#   color: #f1f1f1;
# }
# #T_6bf1b_row14_col0, #T_6bf1b_row15_col0 {
#   background-color: #2c0594;
#   color: #f1f1f1;
# }
# #T_6bf1b_row16_col0 {
#   background-color: #2a0593;
#   color: #f1f1f1;
# }
# #T_6bf1b_row16_col1 {
#   background-color: #6001a6;
#   color: #f1f1f1;
# }
# #T_6bf1b_row17_col0 {
#   background-color: #240691;
#   color: #f1f1f1;
# }
# #T_6bf1b_row17_col1 {
#   background-color: #8a09a5;
#   color: #f1f1f1;
# }
# #T_6bf1b_row18_col1 {
#   background-color: #6700a8;
#   color: #f1f1f1;
# }
# #T_6bf1b_row19_col0, #T_6bf1b_row20_col0 {
#   background-color: #1b068d;
#   color: #f1f1f1;
# }
# #T_6bf1b_row19_col1 {
#   background-color: #5601a4;
#   color: #f1f1f1;
# }
# #T_6bf1b_row21_col0 {
#   background-color: #130789;
#   color: #f1f1f1;
# }
# #T_6bf1b_row21_col1 {
#   background-color: #fada24;
#   color: #000000;
# }
# #T_6bf1b_row22_col0, #T_6bf1b_row23_col0, #T_6bf1b_row24_col1 {
#   background-color: #100788;
#   color: #f1f1f1;
# }
# #T_6bf1b_row22_col1 {
#   background-color: #5901a5;
#   color: #f1f1f1;
# }
# #T_6bf1b_row23_col1 {
#   background-color: #280592;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6bf1b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bf1b_level0_col0" class="col_heading level0 col0" >count_mother</th>
#       <th id="T_6bf1b_level0_col1" class="col_heading level0 col1" >count_bible</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >lemma</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bf1b_level0_row0" class="row_heading level0 row0" >мать</th>
#       <td id="T_6bf1b_row0_col0" class="data row0 col0" >983</td>
#       <td id="T_6bf1b_row0_col1" class="data row0 col1" >366</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row1" class="row_heading level0 row1" >сказать</th>
#       <td id="T_6bf1b_row1_col0" class="data row1 col0" >697</td>
#       <td id="T_6bf1b_row1_col1" class="data row1 col1" >5844</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row2" class="row_heading level0 row2" >человек</th>
#       <td id="T_6bf1b_row2_col0" class="data row2 col0" >680</td>
#       <td id="T_6bf1b_row2_col1" class="data row2 col1" >2349</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row3" class="row_heading level0 row3" >говорить</th>
#       <td id="T_6bf1b_row3_col0" class="data row3 col0" >569</td>
#       <td id="T_6bf1b_row3_col1" class="data row3 col1" >3732</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row4" class="row_heading level0 row4" >рука</th>
#       <td id="T_6bf1b_row4_col0" class="data row4 col0" >478</td>
#       <td id="T_6bf1b_row4_col1" class="data row4 col1" >1889</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row5" class="row_heading level0 row5" >павел</th>
#       <td id="T_6bf1b_row5_col0" class="data row5 col0" >414</td>
#       <td id="T_6bf1b_row5_col1" class="data row5 col1" >155</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row6" class="row_heading level0 row6" >глаз</th>
#       <td id="T_6bf1b_row6_col0" class="data row6 col0" >412</td>
#       <td id="T_6bf1b_row6_col1" class="data row6 col1" >549</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row7" class="row_heading level0 row7" >лицо</th>
#       <td id="T_6bf1b_row7_col0" class="data row7 col0" >396</td>
#       <td id="T_6bf1b_row7_col1" class="data row7 col1" >683</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row8" class="row_heading level0 row8" >голова</th>
#       <td id="T_6bf1b_row8_col0" class="data row8 col0" >371</td>
#       <td id="T_6bf1b_row8_col1" class="data row8 col1" >429</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row9" class="row_heading level0 row9" >спросить</th>
#       <td id="T_6bf1b_row9_col0" class="data row9 col0" >258</td>
#       <td id="T_6bf1b_row9_col1" class="data row9 col1" >172</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row10" class="row_heading level0 row10" >голос</th>
#       <td id="T_6bf1b_row10_col0" class="data row10 col0" >257</td>
#       <td id="T_6bf1b_row10_col1" class="data row10 col1" >384</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row11" class="row_heading level0 row11" >николай</th>
#       <td id="T_6bf1b_row11_col0" class="data row11 col0" >242</td>
#       <td id="T_6bf1b_row11_col1" class="data row11 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row12" class="row_heading level0 row12" >видеть</th>
#       <td id="T_6bf1b_row12_col0" class="data row12 col0" >232</td>
#       <td id="T_6bf1b_row12_col1" class="data row12 col1" >953</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row13" class="row_heading level0 row13" >идти</th>
#       <td id="T_6bf1b_row13_col0" class="data row13 col0" >225</td>
#       <td id="T_6bf1b_row13_col1" class="data row13 col1" >950</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row14" class="row_heading level0 row14" >жизнь</th>
#       <td id="T_6bf1b_row14_col0" class="data row14 col0" >222</td>
#       <td id="T_6bf1b_row14_col1" class="data row14 col1" >561</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row15" class="row_heading level0 row15" >слово</th>
#       <td id="T_6bf1b_row15_col0" class="data row15 col0" >220</td>
#       <td id="T_6bf1b_row15_col1" class="data row15 col1" >1584</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row16" class="row_heading level0 row16" >знать</th>
#       <td id="T_6bf1b_row16_col0" class="data row16 col0" >219</td>
#       <td id="T_6bf1b_row16_col1" class="data row16 col1" >1017</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row17" class="row_heading level0 row17" >быть</th>
#       <td id="T_6bf1b_row17_col0" class="data row17 col0" >210</td>
#       <td id="T_6bf1b_row17_col1" class="data row17 col1" >1647</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row18" class="row_heading level0 row18" >сердце</th>
#       <td id="T_6bf1b_row18_col0" class="data row18 col0" >202</td>
#       <td id="T_6bf1b_row18_col1" class="data row18 col1" >1139</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row19" class="row_heading level0 row19" >мочь</th>
#       <td id="T_6bf1b_row19_col0" class="data row19 col0" >197</td>
#       <td id="T_6bf1b_row19_col1" class="data row19 col1" >878</td>
#     </tr>
#     <tr>
#       <th id="T_6bf1b_level0_row20" clas

# %%
def compare_list_frequency(*args,
                           consider_order=False,
                           consider_duplicates=True,
                           handle_unhashable=False,
                           key=None,
                           frequency_format="dict"):    
    list_hit_list = []
    for arg in args:
        list_hit_dict = {}
        other_args = args[:args.index(arg)] + args[args.index(arg)+1:]
        for word in set(arg):
            word_hit_count = 0
            for other_arg in other_args:
                word_hit_count += list(other_arg).count(word)
            if word_hit_count > 0:
                list_hit_dict[word] = word_hit_count
            #print(f"{word}: {list(bible_lemmas[:1000]).count(word)}")
        list_hit_list.append(list_hit_dict)

    return(list_hit_list)

# %%
comparison_lists = compare_list_frequency(list(mother_lemmas), list(bible_lemmas), list(confession_lemmas))

# %%
mother_lemmas.value_counts().to_frame()
# Out:
#              count
# lemma
# мать           983
# сказать        697
# человек        680
# говорить       569
# рука           478
# ...            ...
# нагнать          1
# отравить         1
# оголить          1
# возбуждаясь      1
# десятина         1
#
# [7259 rows x 1 columns]

# %%
compDf = pd.DataFrame(comparison_lists).transpose(copy=True).fillna(0).astype(int)
compDf.columns = ['mother', 'bible', 'confession']
compDf = compDf.fillna(0).astype(int, errors='ignore')
compDf.sample(25).style.background_gradient(cmap='plasma')
# Out:
# <style type="text/css">
# #T_4b913_row0_col0, #T_4b913_row0_col1, #T_4b913_row1_col0, #T_4b913_row3_col0, #T_4b913_row6_col0, #T_4b913_row6_col1, #T_4b913_row6_col2, #T_4b913_row8_col0, #T_4b913_row11_col2, #T_4b913_row12_col2, #T_4b913_row15_col2, #T_4b913_row16_col0, #T_4b913_row16_col1, #T_4b913_row16_col2, #T_4b913_row19_col0, #T_4b913_row21_col1, #T_4b913_row22_col0, #T_4b913_row22_col2, #T_4b913_row23_col0, #T_4b913_row24_col0, #T_4b913_row24_col1 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_4b913_row0_col2, #T_4b913_row5_col2, #T_4b913_row15_col0 {
#   background-color: #130789;
#   color: #f1f1f1;
# }
# #T_4b913_row1_col1, #T_4b913_row2_col1, #T_4b913_row5_col1, #T_4b913_row13_col1 {
#   background-color: #2c0594;
#   color: #f1f1f1;
# }
# #T_4b913_row1_col2 {
#   background-color: #a01a9c;
#   color: #f1f1f1;
# }
# #T_4b913_row2_col0 {
#   background-color: #d04d73;
#   color: #f1f1f1;
# }
# #T_4b913_row2_col2 {
#   background-color: #c7427c;
#   color: #f1f1f1;
# }
# #T_4b913_row3_col1, #T_4b913_row13_col0, #T_4b913_row17_col1, #T_4b913_row19_col2 {
#   background-color: #1d068e;
#   color: #f1f1f1;
# }
# #T_4b913_row3_col2 {
#   background-color: #6100a7;
#   color: #f1f1f1;
# }
# #T_4b913_row4_col0 {
#   background-color: #19068c;
#   color: #f1f1f1;
# }
# #T_4b913_row4_col1, #T_4b913_row10_col1 {
#   background-color: #8808a6;
#   color: #f1f1f1;
# }
# #T_4b913_row4_col2, #T_4b913_row19_col1, #T_4b913_row20_col0, #T_4b913_row23_col1 {
#   background-color: #260591;
#   color: #f1f1f1;
# }
# #T_4b913_row5_col0, #T_4b913_row11_col0, #T_4b913_row17_col0, #T_4b913_row17_col2, #T_4b913_row21_col0, #T_4b913_row21_col2, #T_4b913_row23_col2, #T_4b913_row24_col2 {
#   background-color: #100788;
#   color: #f1f1f1;
# }
# #T_4b913_row7_col0 {
#   background-color: #fdb42f;
#   color: #000000;
# }
# #T_4b913_row7_col1, #T_4b913_row14_col0, #T_4b913_row14_col2 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_4b913_row7_col2 {
#   background-color: #fdaf31;
#   color: #000000;
# }
# #T_4b913_row8_col1, #T_4b913_row8_col2, #T_4b913_row11_col1, #T_4b913_row15_col1, #T_4b913_row22_col1 {
#   background-color: #16078a;
#   color: #f1f1f1;
# }
# #T_4b913_row9_col0, #T_4b913_row13_col2 {
#   background-color: #20068f;
#   color: #f1f1f1;
# }
# #T_4b913_row9_col1 {
#   background-color: #c03a83;
#   color: #f1f1f1;
# }
# #T_4b913_row9_col2 {
#   background-color: #2f0596;
#   color: #f1f1f1;
# }
# #T_4b913_row10_col0, #T_4b913_row20_col1 {
#   background-color: #7e03a8;
#   color: #f1f1f1;
# }
# #T_4b913_row10_col2 {
#   background-color: #6e00a8;
#   color: #f1f1f1;
# }
# #T_4b913_row12_col0 {
#   background-color: #6400a7;
#   color: #f1f1f1;
# }
# #T_4b913_row12_col1 {
#   background-color: #6001a6;
#   color: #f1f1f1;
# }
# #T_4b913_row14_col1 {
#   background-color: #f3ee27;
#   color: #000000;
# }
# #T_4b913_row18_col0 {
#   background-color: #a62098;
#   color: #f1f1f1;
# }
# #T_4b913_row18_col1 {
#   background-color: #f1f426;
#   color: #000000;
# }
# #T_4b913_row18_col2 {
#   background-color: #b22b8f;
#   color: #f1f1f1;
# }
# #T_4b913_row20_col2 {
#   background-color: #310597;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4b913">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b913_level0_col0" class="col_heading level0 col0" >mother</th>
#       <th id="T_4b913_level0_col1" class="col_heading level0 col1" >bible</th>
#       <th id="T_4b913_level0_col2" class="col_heading level0 col2" >confession</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b913_level0_row0" class="row_heading level0 row0" >подвигаться</th>
#       <td id="T_4b913_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4b913_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_4b913_row0_col2" class="data row0 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row1" class="row_heading level0 row1" >конь</th>
#       <td id="T_4b913_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_4b913_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_4b913_row1_col2" class="data row1 col2" >164</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row2" class="row_heading level0 row2" >исполнить</th>
#       <td id="T_4b913_row2_col0" class="data row2 col0" >225</td>
#       <td id="T_4b913_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_4b913_row2_col2" class="data row2 col2" >227</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row3" class="row_heading level0 row3" >блаженный</th>
#       <td id="T_4b913_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_4b913_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_4b913_row3_col2" class="data row3 col2" >84</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row4" class="row_heading level0 row4" >оглядываться</th>
#       <td id="T_4b913_row4_col0" class="data row4 col0" >7</td>
#       <td id="T_4b913_row4_col1" class="data row4 col1" >21</td>
#       <td id="T_4b913_row4_col2" class="data row4 col2" >20</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row5" class="row_heading level0 row5" >измять</th>
#       <td id="T_4b913_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_4b913_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_4b913_row5_col2" class="data row5 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row6" class="row_heading level0 row6" >призрачный</th>
#       <td id="T_4b913_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_4b913_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_4b913_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row7" class="row_heading level0 row7" >добрый</th>
#       <td id="T_4b913_row7_col0" class="data row7 col0" >361</td>
#       <td id="T_4b913_row7_col1" class="data row7 col1" >75</td>
#       <td id="T_4b913_row7_col2" class="data row7 col2" >388</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row8" class="row_heading level0 row8" >богохульствовать</th>
#       <td id="T_4b913_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_4b913_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_4b913_row8_col2" class="data row8 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row9" class="row_heading level0 row9" >лошадь</th>
#       <td id="T_4b913_row9_col0" class="data row9 col0" >12</td>
#       <td id="T_4b913_row9_col1" class="data row9 col1" >34</td>
#       <td id="T_4b913_row9_col2" class="data row9 col2" >28</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row10" class="row_heading level0 row10" >нищий</th>
#       <td id="T_4b913_row10_col0" class="data row10 col0" >109</td>
#       <td id="T_4b913_row10_col1" class="data row10 col1" >21</td>
#       <td id="T_4b913_row10_col2" class="data row10 col2" >98</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row11" class="row_heading level0 row11" >объятие</th>
#       <td id="T_4b913_row11_col0" class="data row11 col0" >3</td>
#       <td id="T_4b913_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_4b913_row11_col2" class="data row11 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row12" class="row_heading level0 row12" >твердый</th>
#       <td id="T_4b913_row12_col0" class="data row12 col0" >80</td>
#       <td id="T_4b913_row12_col1" class="data row12 col1" >13</td>
#       <td id="T_4b913_row12_col2" class="data row12 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row13" class="row_heading level0 row13" >колючий</th>
#       <td id="T_4b913_row13_col0" class="data row13 col0" >11</td>
#       <td id="T_4b913_row13_col1" class="data row13 col1" >4</td>
#       <td id="T_4b913_row13_col2" class="data row13 col2" >13</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row14" class="row_heading level0 row14" >давать</th>
#       <td id="T_4b913_row14_col0" class="data row14 col0" >433</td>
#       <td id="T_4b913_row14_col1" class="data row14 col1" >73</td>
#       <td id="T_4b913_row14_col2" class="data row14 col2" >472</td>
#     </tr>
#     <tr>
#       <th id="T_4b913_level0_row15" class="row_heading level0 row15" >навязать</th>
#       <td id="T_4b913_row15_col0" class="data row15 col0" >5</td>
#       <td id="T_4b913_row15_col1" class

# %%
#mcompDf = compDf.sort_values('mother', axis=0, ascending=False)[:25].style.background_gradient(cmap='plasma')
bcompDf = compDf.sort_values('bible', axis=0, ascending=False)[:25].style.background_gradient(cmap='plasma')
#ccompDf = compDf.sort_values('confession', axis=0, ascending=False)[:25].style.background_gradient(cmap='plasma')

# %%
bcompDf
# Out:
# <style type="text/css">
# #T_cb3b9_row0_col0 {
#   background-color: #be3885;
#   color: #f1f1f1;
# }
# #T_cb3b9_row0_col1, #T_cb3b9_row3_col0, #T_cb3b9_row3_col2 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_cb3b9_row0_col2 {
#   background-color: #c23c81;
#   color: #f1f1f1;
# }
# #T_cb3b9_row1_col0 {
#   background-color: #f1834c;
#   color: #f1f1f1;
# }
# #T_cb3b9_row1_col1 {
#   background-color: #f6e626;
#   color: #000000;
# }
# #T_cb3b9_row1_col2 {
#   background-color: #eb7655;
#   color: #f1f1f1;
# }
# #T_cb3b9_row2_col0 {
#   background-color: #260591;
#   color: #f1f1f1;
# }
# #T_cb3b9_row2_col1 {
#   background-color: #fcd225;
#   color: #000000;
# }
# #T_cb3b9_row2_col2, #T_cb3b9_row20_col2 {
#   background-color: #6c00a8;
#   color: #f1f1f1;
# }
# #T_cb3b9_row3_col1, #T_cb3b9_row19_col2 {
#   background-color: #ef7c51;
#   color: #f1f1f1;
# }
# #T_cb3b9_row4_col0 {
#   background-color: #9613a1;
#   color: #f1f1f1;
# }
# #T_cb3b9_row4_col1 {
#   background-color: #b22b8f;
#   color: #f1f1f1;
# }
# #T_cb3b9_row4_col2 {
#   background-color: #a51f99;
#   color: #f1f1f1;
# }
# #T_cb3b9_row5_col0 {
#   background-color: #3e049c;
#   color: #f1f1f1;
# }
# #T_cb3b9_row5_col1 {
#   background-color: #a21d9a;
#   color: #f1f1f1;
# }
# #T_cb3b9_row5_col2, #T_cb3b9_row23_col0 {
#   background-color: #5502a4;
#   color: #f1f1f1;
# }
# #T_cb3b9_row6_col0 {
#   background-color: #48039f;
#   color: #f1f1f1;
# }
# #T_cb3b9_row6_col1 {
#   background-color: #99159f;
#   color: #f1f1f1;
# }
# #T_cb3b9_row6_col2, #T_cb3b9_row12_col2 {
#   background-color: #5c01a6;
#   color: #f1f1f1;
# }
# #T_cb3b9_row7_col0, #T_cb3b9_row10_col2, #T_cb3b9_row20_col0 {
#   background-color: #6100a7;
#   color: #f1f1f1;
# }
# #T_cb3b9_row7_col1 {
#   background-color: #7e03a8;
#   color: #f1f1f1;
# }
# #T_cb3b9_row7_col2 {
#   background-color: #6300a7;
#   color: #f1f1f1;
# }
# #T_cb3b9_row8_col0 {
#   background-color: #2f0596;
#   color: #f1f1f1;
# }
# #T_cb3b9_row8_col1 {
#   background-color: #7a02a8;
#   color: #f1f1f1;
# }
# #T_cb3b9_row8_col2 {
#   background-color: #4b03a1;
#   color: #f1f1f1;
# }
# #T_cb3b9_row9_col0, #T_cb3b9_row9_col2, #T_cb3b9_row22_col1, #T_cb3b9_row23_col1, #T_cb3b9_row24_col1 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_cb3b9_row9_col1, #T_cb3b9_row11_col2 {
#   background-color: #6600a7;
#   color: #f1f1f1;
# }
# #T_cb3b9_row10_col0 {
#   background-color: #5901a5;
#   color: #f1f1f1;
# }
# #T_cb3b9_row10_col1, #T_cb3b9_row14_col2 {
#   background-color: #4903a0;
#   color: #f1f1f1;
# }
# #T_cb3b9_row11_col0, #T_cb3b9_row23_col2 {
#   background-color: #5e01a6;
#   color: #f1f1f1;
# }
# #T_cb3b9_row11_col1, #T_cb3b9_row24_col0 {
#   background-color: #46039f;
#   color: #f1f1f1;
# }
# #T_cb3b9_row12_col0 {
#   background-color: #5601a4;
#   color: #f1f1f1;
# }
# #T_cb3b9_row12_col1, #T_cb3b9_row13_col1 {
#   background-color: #44039e;
#   color: #f1f1f1;
# }
# #T_cb3b9_row13_col0 {
#   background-color: #8405a7;
#   color: #f1f1f1;
# }
# #T_cb3b9_row13_col2 {
#   background-color: #8707a6;
#   color: #f1f1f1;
# }
# #T_cb3b9_row14_col0 {
#   background-color: #3c049b;
#   color: #f1f1f1;
# }
# #T_cb3b9_row14_col1, #T_cb3b9_row16_col2 {
#   background-color: #41049d;
#   color: #f1f1f1;
# }
# #T_cb3b9_row15_col0 {
#   background-color: #8808a6;
#   color: #f1f1f1;
# }
# #T_cb3b9_row15_col1 {
#   background-color: #3f049c;
#   color: #f1f1f1;
# }
# #T_cb3b9_row15_col2 {
#   background-color: #8a09a5;
#   color: #f1f1f1;
# }
# #T_cb3b9_row16_col0 {
#   background-color: #2a0593;
#   color: #f1f1f1;
# }
# #T_cb3b9_row16_col1 {
#   background-color: #2e0595;
#   color: #f1f1f1;
# }
# #T_cb3b9_row17_col0, #T_cb3b9_row21_col1 {
#   background-color: #100788;
#   color: #f1f1f1;
# }
# #T_cb3b9_row17_col1 {
#   background-color: #240691;
#   color: #f1f1f1;
# }
# #T_cb3b9_row17_col2 {
#   background-color: #310597;
#   color: #f1f1f1;
# }
# #T_cb3b9_row18_col0 {
#   background-color: #220690;
#   color: #f1f1f1;
# }
# #T_cb3b9_row18_col1 {
#   background-color: #1d068e;
#   color: #f1f1f1;
# }
# #T_cb3b9_row18_col2 {
#   background-color: #330597;
#   color: #f1f1f1;
# }
# #T_cb3b9_row19_col0 {
#   background-color: #f9983e;
#   color: #000000;
# }
# #T_cb3b9_row19_col1, #T_cb3b9_row20_col1 {
#   background-color: #130789;
#   color: #f1f1f1;
# }
# #T_cb3b9_row21_col0 {
#   background-color: #da5a6a;
#   color: #f1f1f1;
# }
# #T_cb3b9_row21_col2 {
#   background-color: #d04d73;
#   color: #f1f1f1;
# }
# #T_cb3b9_row22_col0 {
#   background-color: #19068c;
#   color: #f1f1f1;
# }
# #T_cb3b9_row22_col2 {
#   background-color: #280592;
#   color: #f1f1f1;
# }
# #T_cb3b9_row24_col2 {
#   background-color: #5002a2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cb3b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb3b9_level0_col0" class="col_heading level0 col0" >mother</th>
#       <th id="T_cb3b9_level0_col1" class="col_heading level0 col1" >bible</th>
#       <th id="T_cb3b9_level0_col2" class="col_heading level0 col2" >confession</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb3b9_level0_row0" class="row_heading level0 row0" >человек</th>
#       <td id="T_cb3b9_row0_col0" class="data row0 col0" >2763</td>
#       <td id="T_cb3b9_row0_col1" class="data row0 col1" >1094</td>
#       <td id="T_cb3b9_row0_col2" class="data row0 col2" >3029</td>
#     </tr>
#     <tr>
#       <th id="T_cb3b9_level0_row1" class="row_heading level0 row1" >говорить</th>
#       <td id="T_cb3b9_row1_col0" class="data row1 col0" >4220</td>
#       <td id="T_cb3b9_row1_col1" class="data row1 col1" >1057</td>
#       <td id="T_cb3b9_row1_col2" class="data row1 col2" >4301</td>
#     </tr>
#     <tr>
#       <th id="T_cb3b9_level0_row2" class="row_heading level0 row2" >мать</th>
#       <td id="T_cb3b9_row2_col0" class="data row2 col0" >400</td>
#       <td id="T_cb3b9_row2_col1" class="data row2 col1" >1017</td>
#       <td id="T_cb3b9_row2_col2" class="data row2 col2" >1349</td>
#     </tr>
#     <tr>
#       <th id="T_cb3b9_level0_row3" class="row_heading level0 row3" >сказать</th>
#       <td id="T_cb3b9_row3_col0" class="data row3 col0" >5969</td>
#       <td id="T_cb3b9_row3_col1" class="data row3 col1" >822</td>
#       <td id="T_cb3b9_row3_col2" class="data row3 col2" >6541</td>
#     </tr>
#     <tr>
#       <th id="T_cb3b9_level0_row4" class="row_heading level0 row4" >рука</th>
#       <td id="T_cb3b9_row4_col0" class="data row4 col0" >2006</td>
#       <td id="T_cb3b9_row4_col1" class="data row4 col1" >595</td>
#       <td id="T_cb3b9_row4_col2" class="data row4 col2" >2367</td>
#     </tr>
#     <tr>
#       <th id="T_cb3b9_level0_row5" class="row_heading level0 row5" >глаз</th>
#       <td id="T_cb3b9_row5_col0" class="data row5 col0" >687</td>
#       <td id="T_cb3b9_row5_col1" class="data row5 col1" >550</td>
#       <td id="T_cb3b9_row5_col2" class="data row5 col2" >961</td>
#     </tr>
#     <tr>
#       <th id="T_cb3b9_level0_row6" class="row_heading level0 row6" >лицо</th>
#       <td id="T_cb3b9_row6_col0" class="data row6 col0" >816</td>
#       <td id="T_cb3b9_row6_col1" class="data row6 col1" >529</td>
#       <td id="T_cb3b9_row6_col2" class="data row6 col2" >1079</td>
#     </tr>
#     <tr>
#       <th id="T_cb3b9_level0_row7" class="row_heading level0 row7" >видеть</th>
#       <td id="T_cb3b9_row7_col0" class="data row7 col0" >1186</td>
#       <td id="T_cb3b9_row7_col1" class="data row7 col1" >465</td>
#       <td id="T_cb3b9_row7_col2" class="data row7 col2" >1185</td>
#     </tr>
#     <tr>
#       <th id="T_cb3b9_level0_row8" class="row_heading level0 row8" >голова</th>
#       <td id="T_cb3b9_row8_col0" class="data row8 col0" >513</td>
#       <td id="T_cb3b9_row8_col1" class="data row8 col1" >455</td>
#       <td id="T_cb3b9_row8_col2" class="data row8 col2" >800</td>
#     </tr>
#     <tr>
#       <th id="T_cb3b9_level0_row9" class="row_heading level0 row9" >павел</th>
#       <td id="T_cb3b9_row9_col0" class="data row9 col0" >155</td>
#       <td id="T_cb3b9_row9_col1" class="data row9 col1" >414</td>
#       <td id="T_cb3b9_row9_col2" class="data row9 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_cb3b9_level0_row10" class="row_heading level0 row10" >идти</th>
#       <td id="T_cb3b9_row10_col0" class="data row10 col0" >1079</td>
#       <td id="T_cb3b9_row10_col1" class="data row10 col1" >354</td>
#       <td id="T_cb3b9_row10_col2" class="data row10 col2" >1175</td>
#     </tr>
#     <tr>
#       <th id="T_cb3b9_

# %%
def ListSplit(lst, numGroups, sort=True): 
    """Takes a list and a number and splits the 
    list into evenly divided n groups (as much as possible)"""
    # choose to sort list by ascending
    if sort: 
        lst.sort()
    # get length of list given to sort
    listLen = len(lst)
    # groupLen is the maximum number of items per group to allow for the most groups <= numGroups in a list (numGroups-1 OR numGroups)
    groupLen = (listLen//numGroups) + (listLen % numGroups > 0)
    # yield generator object of nested listed with length of numGroups 
    for i in range(0,len(lst), groupLen): 
        yield lst[i:i+groupLen]

def token_window(lemma_array, window_size):
    token_window_array = np.array([])
    token_window_array = np.array([np.array(lemma_array[i:i+window_size]) for i in range(len(lemma_array)-(window_size-1))])
    return token_window_array

def token_window_mp(lemma_array, window_size):
    #token_window_array = np.array([])
    token_window_array = enumerate([list(lemma_array[i:i+window_size]) for i in range(len(lemma_array)-(window_size-1))])
    return token_window_array

def get_sim_count(child_window_array, parent_window_array, order_matters=False):
    work_sim_count = 0
    work_sim = []
    for child_window in child_window_array:
        child_sim = {}
        #print(f"child window: {child_window}")
        child_window_sim_total_count = 0
        for parent_window in parent_window_array:
            #print(f"parent window: {parent_window}")
            child_window_sim_sub_count = 0
            for i in range(len(child_window)):
                if order_matters:
                    if child_window[1][i] == parent_window[1][i]:
                        child_window_sim_total_count+=1
                        child_window_sim_sub_count+=1
                else:
                    if child_window[1][i] in parent_window[1]:
                        #print(f"{child_window[i]} is in parent!")
                        child_window_sim_total_count+=1
                        child_window_sim_sub_count+=1
                    #else:
                        #print(f"{child_window[i]} is not in parent!")
            child_sim.update({parent_window[0]: child_window_sim_sub_count})
        #print(f"{child_window}: {child_window_sim_total_count}")
        work_sim.append({child_window_sim_total_count: child_sim})
    return work_sim

def dna_test_windows(child_lemmas, parent_lemmas, window_size=10):
    sim_counter = 0
    #sim_list = np.array([])
    parent_window_array = token_window(parent_lemmas, window_size)
    child_window_array = token_window(child_lemmas, window_size)
    sim_list = get_sim_count(child_window_array, parent_window_array)
    #print(sim_list)
    return sim_list

def dna_test_windows_mp(child_lemmas, parent_lemmas, window_size=10):
    #child_lemmas, parent_lemmas = cnp_lemmas[0], cnp_lemmas[1]
    #print(f"Child lemmas: {child_lemmas}")
    #print(f"Parent lemmas: {parent_lemmas[:10]}")
    sim_counter = 0
    sim_list = np.array([])
    parent_window_array = token_window_mp(parent_lemmas, window_size)
    child_window_array = token_window_mp(child_lemmas, window_size)
    sim_list = get_sim_count(child_window_array, parent_window_array)
    return sim_list

def window_count_sim_mp(child_window_array, parent_window_array, order_matters=False):
    sim_count_tuples = {}
    for (c_sub_array_id, c_sub_array_list) in child_window_array:
        c_sub_sim_count = 0
        for (p_sub_array_id, p_sub_array_list) in parent_window_array:
            c_p_sim_count = 0
            for i in range(len(c_sub_array_list)):
                if order_matters:
                    if c_sub_array_list[i] == p_sub_array_list[i]:
                        c_sub_sim_count += 1
                        c_p_sim_count += 1
                else:
                    if c_sub_array_list[i] in p_sub_array_list:
                        c_sub_sim_count += 1
                        c_p_sim_count += 1
            sim_count_tuples[(c_sub_array_id, p_sub_array_id)] = c_p_sim_count
    return sim_count_tuples

# %%
def list_split(lst, numGroups, sort=True): 
    """Takes a list and a number and splits the 
    list into evenly divided n groups (as much as possible)"""
    # choose to sort list by ascending
    if sort: 
        lst.sort()
    # get length of list given to sort
    listLen = len(lst)
    # groupLen is the maximum number of items per group to allow for the most groups <= numGroups in a list (numGroups-1 OR numGroups)
    groupLen = (listLen//numGroups) + (listLen % numGroups > 0)
    # yield generator object of nested listed with length of numGroups 
    for i in range(0,len(lst), groupLen): 
        yield lst[i:i+groupLen]

def token_window_mp(lemma_array, window_size):
    #token_window_array = np.array([])
    token_window_array = enumerate([list(lemma_array[i:i+window_size]) for i in range(len(lemma_array)-(window_size-1))])
    return token_window_array

def window_count_sim_mp(child_window_array, parent_window_array, order_matters=False):
    sim_count_tuples = {}
    for (c_sub_array_id, c_sub_array_list) in child_window_array:
        c_sub_sim_count = 0
        for (p_sub_array_id, p_sub_array_list) in parent_window_array:
            c_p_sim_count = 0
            for i in range(len(c_sub_array_list)):
                if order_matters:
                    if c_sub_array_list[i] == p_sub_array_list[i]:
                        c_sub_sim_count += 1
                        c_p_sim_count += 1
                else:
                    if c_sub_array_list[i] in p_sub_array_list:
                        c_sub_sim_count += 1
                        c_p_sim_count += 1
            if order_matters: 
                if c_p_sim_count > 1: 
                    sim_count_tuples[(c_sub_array_id, p_sub_array_id)] = c_p_sim_count
            elif c_p_sim_count > 2: 
                sim_count_tuples[(c_sub_array_id, p_sub_array_id)] = c_p_sim_count
    return sim_count_tuples

def dna_test_windows_mp(child_lemmas, parent_lemmas, window_size=10):
    sim_list = {}
    parent_window_array = token_window_mp(parent_lemmas, window_size)
    child_window_array = token_window_mp(child_lemmas, window_size)
    sim_list = window_count_sim_mp(child_window_array, parent_window_array)
    return sim_list

# %%
child_window_array = list(token_window_mp(mother_lemmas, 7))
parent_window_array = list(token_window_mp(bible_lemmas, 7))

# %%
len(child_window_array)
# Out:
# 46830

# %%
len(parent_window_array)
# Out:
# 345084

# %%
# %%time
if __name__ == "__main__":
    pool = Pool(processes=num_cores)
    #workerAssignments = ((x, bible_lemmas) for x in ListSplit(mother_lemmas[:198], num_cores, False))
    starmap_list = list(zip(list_split(child_window_array, num_cores), list_split(parent_window_array, num_cores)))
    print(f"Splitting into {num_cores} groups")
    start_time = time.time()
    sim_tuples = pool.starmap(window_count_sim_mp, starmap_list, chunksize=2)
    print(f"Finished in {round(time.time()-start_time, 3)} seconds.")
    pool.close()
    pool.join()
    #print(sim_tuples)
# Out:
# Splitting into 38 groups
# Finished in 24.683 seconds.
# CPU times: user 903 ms, sys: 4.18 s, total: 5.08 s
# Wall time: 25.6 s

# %%
for i in range(len(sim_tuples)):
    print(f"len({i}): {len(sim_tuples[i])}")
# Out:
# len(0): 721
# len(1): 2684
# len(2): 167
# len(3): 1183
# len(4): 621
# len(5): 3337
# len(6): 655
# len(7): 1221
# len(8): 3692
# len(9): 2820
# len(10): 847
# len(11): 2071
# len(12): 2428
# len(13): 1450
# len(14): 977
# len(15): 813
# len(16): 1999
# len(17): 604
# len(18): 341
# len(19): 941
# len(20): 461
# len(21): 817
# len(22): 1468
# len(23): 511
# len(24): 990
# len(25): 1136
# len(26): 118
# len(27): 2070
# len(28): 220
# len(29): 331
# len(30): 603
# len(31): 3293
# len(32): 571
# len(33): 739
# len(34): 1147
# len(35): 487
# len(36): 461
# len(37): 602

# %%
total_sim_tuples = {}
for t in sim_tuples:
    total_sim_tuples.update(t)

# %%
len(total_sim_tuples)
# Out:
# 45597

# %%
sorted_sim_tuples = sorted(total_sim_tuples.items(), key=lambda x:x[1], reverse=True)
sorted_sim_tuples
# Out:
# [((5232, 40313), 6),
#  ((5232, 40314), 6),
#  ((5232, 40315), 6),
#  ((5232, 40316), 6),
#  ((5232, 40317), 6),
#  ((5232, 40318), 6),
#  ((5232, 42909), 6),
#  ((5232, 42910), 6),
#  ((5232, 42911), 6),
#  ((5232, 42912), 6),
#  ((15376, 114312), 6),
#  ((15376, 114313), 6),
#  ((15376, 115154), 6),
#  ((15376, 115157), 6),
#  ((15376, 115158), 6),
#  ((15376, 115159), 6),
#  ((15376, 115160), 6),
#  ((5231, 40313), 5),
#  ((5231, 40314), 5),
#  ((5231, 40315), 5),
#  ((5231, 40316), 5),
#  ((5231, 40317), 5),
#  ((5231, 40318), 5),
#  ((5231, 42909), 5),
#  ((5231, 42910), 5),
#  ((5231, 42911), 5),
#  ((5231, 42912), 5),
#  ((5233, 40313), 5),
#  ((5233, 40314), 5),
#  ((5233, 40315), 5),
#  ((5233, 40316), 5),
#  ((5233, 40317), 5),
#  ((5233, 40318), 5),
#  ((5233, 42909), 5),
#  ((5233, 42910), 5),
#  ((5233, 42911), 5),
#  ((5233, 42912), 5),
#  ((5234, 40313), 5),
#  ((5234, 40314), 5),
#  ((5234, 40315), 5),
#  ((5234, 40316), 5),
#  ((5234, 40317), 5),
#  ((5234, 40318), 5),
#  ((5234, 42909), 5),
#  ((5234, 42910), 5),
#  ((5234, 42911), 5),
#  ((5234, 42912), 5),
#  ((7028, 52844), 5),
#  ((7028, 52845), 5),
#  ((15375, 114312), 5),
#  ((15375, 114313), 5),
#  ((15375, 115154), 5),
#  ((15375, 115157), 5),
#  ((15375, 115158), 5),
#  ((15375, 115159), 5),
#  ((15375, 115160), 5),
#  ((15376, 113587), 5),
#  ((15376, 113588), 5),
#  ((15376, 114314), 5),
#  ((15376, 114345), 5),
#  ((15376, 114346), 5),
#  ((15376, 114347), 5),
#  ((15376, 114508), 5),
#  ((15376, 114509), 5),
#  ((15376, 115153), 5),
#  ((15376, 115161), 5),
#  ((15376, 115167), 5),
#  ((19012, 140255), 4),
#  ((19012, 140256), 4),
#  ((19013, 140255), 4),
#  ((19013, 140256), 4),
#  ((19014, 140255), 4),
#  ((19014, 140256), 4),
#  ((19015, 139483), 4),
#  ((19015, 139484), 4),
#  ((19693, 139132), 4),
#  ((19693, 139133), 4),
#  ((19694, 139132), 4),
#  ((19694, 139133), 4),
#  ((19695, 139132), 4),
#  ((19695, 139133), 4),
#  ((19697, 139132), 4),
#  ((19697, 139133), 4),
#  ((19697, 139134), 4),
#  ((19697, 139135), 4),
#  ((19697, 139136), 4),
#  ...]

# %%
motherTokenDf.loc[motherTokenDf.p_id == 693]
# Out:
#       p_id start stop       text token_id head_id     rel    pos       lemma  \
# id
# 14305  693    10   12         Мы      1_2     1_7   nsubj   PRON          мы
# 14306  693    13   19     всегда      1_3     1_7  advmod    ADV      всегда
# 14307  693    20   21          и      1_4    1_13      cc  CCONJ           и
# 14308  693    22   27      везде      1_5     1_7  advmod    ADV       везде
# 14309  693    31   37     первые      1_7     1_0    root    ADJ      первый
# 14310  693    38   39          в      1_8     1_9    case    ADP           в
# 14311  693    40   46     работе      1_9     1_7    nmod   NOUN      работа
# 14312  693    47   48          и     1_10    1_13      cc  CCONJ           и
# 14313  693    49   51         на     1_11    1_13    case    ADP          на
# 14314  693    52   61  последнем     1_12    1_13    amod    ADJ   последний
# 14315  693    62   67      месте     1_13     1_9    conj   NOUN       место
# 14316  693    68   69          в     1_14    1_15    case    ADP           в
# 14317  693    74   79      жизни     1_15    1_13    nmod   NOUN       жизнь
# 14318  693    81   84        Кто      2_1     2_2   nsubj   PRON         кто
# 14319  693    85   94  заботится      2_2     2_0    root   VERB  заботиться
# 14320  693    95   96          о      2_3     2_4    case    ADP           о
# 14321  693    97  100        нас      2_4     2_2     obl   PRON          мы
# 14322  693   102  105        Кто      3_1     3_2   nsubj   PRON         кто
# 14323  693   106  111      хочет      3_2     3_0    root   VERB      хотеть
# 14324  693   112  115        нам      3_3     3_2    iobj   PRON          мы
# 14325  693   116  121      добра      3_4     3_2     obj   NOUN       добро
# 14326  693   123  126        Кто      4_1     4_2   nsubj   PRON         кто
# 14327  693   127  134    считает      4_2     4_0    root   VERB     считать
# 14328  693   135  138        нас      4_3     4_2     obj   PRON          мы
# 14329  693   143  149     людьми      4_4     4_2   xcomp   NOUN     человек
# 14330  693   151  156      Никто      5_1     5_0    root   PRON       никто
#
#        anim  ...  case degree gender  mood number person tense verb_form  \
# id           ...
# 14305  None  ...   Nom   None   None  None   Plur      1  None      None
# 14306  None  ...  None    Pos   None  None   None   None  None      None
# 14307  None  ...  None   None   None  None   None   None  None      None
# 14308  None  ...  None    Pos   None  None   None   None  None      None
# 14309  None  ...   Nom    Pos   None  None   Plur   None  None      None
# 14310  None  ...  None   None   None  None   None   None  None      None
# 14311  Inan  ...   Loc   None    Fem  None   Sing   None  None      None
# 14312  None  ...  None   None   None  None   None   None  None      None
# 14313  None  ...  None   None   None  None   None   None  None      None
# 103936       Fin   Act    False
# 103937      None  None    False
# 103938      None  None    False
# 103939      None  None     True
# 103940      None  None     True
# 103941      None  None    False
# 103942       Fin   Act     True
# 103943      None  None     True
# 103944      None  None    False
# 103945      None  None    False
# 103946      None  None     True
# 103947       Fin   Act    False
# 103948       Inf   Act    False
# 103949      None  None     True
# 103950      None  None     True
# 103951      None  None     True
# 103952       Fin   Act    False
# 103953      None  None     True
#
# [52 rows x 21 columns]

# %%
motherTokenDf.loc[motherTokenDf.lemma == "заботиться"]
# Out:
#       p_id start stop        text token_id head_id    rel   pos       lemma  \
# id
# 2449    76   799  809  заботиться     7_20    7_18  xcomp  VERB  заботиться
# 14319  693    85   94   заботится      2_2     2_0   root  VERB  заботиться
#
#        anim  ...  case degree gender  mood number person tense verb_form  \
# id           ...
# 2449   None  ...  None   None   None  None   None   None  None       Inf
# 14319  None  ...  None   None   None   Ind   Sing      3  Pres       Fin
#
#       voice stopword
# id
# 2449    Mid    False
# 14319   Mid    False
#
# [2 rows x 21 columns]

# %%
bibleTokenDf.loc[bibleTokenDf.lemma == "поступь"]
# Out:
#          p_id start stop      text token_id head_id    rel    pos    lemma  \
# id
# 46256    2372     3   10   поступи      1_2     1_0   root   NOUN  поступь
# 103925   5374     2    9   поступи      1_2     1_0   root   NOUN  поступь
# 119604   6062    92   99   поступи     1_20    1_16   conj   NOUN  поступь
# 175707   8552   175  182   поступи     2_18    2_10   conj   NOUN  поступь
# 180260   8780     0    7   поступи      1_1     1_0   root   NOUN  поступь
# 318705  16339     0    7   Поступи      1_1     1_0   root  PROPN  поступь
# 376226  20790   113  121  поступью     1_24    1_26   iobj   NOUN  поступь
# 410746  22473   171  178   поступи     1_37     1_6  nsubj   NOUN  поступь
# 512564  27399    12   19   поступи      1_4    1_16  nsubj   NOUN  поступь
#
#         anim  ... case degree gender  mood number person tense verb_form  \
# id            ...
# 46256   Inan  ...  Nom   None   Masc  None   Sing   None  None      None
# 103925  Inan  ...  Nom   None   Masc  None   Sing   None  None      None
# 119604  Inan  ...  Nom   None   Masc  None   Sing   None  None      None
# 175707  Inan  ...  Ins   None   Masc  None   Sing   None  None      None
# 180260  Inan  ...  Gen   None   Masc  None   Sing   None  None      None
# 318705  Anim  ...  Nom   None   Masc  None   Sing   None  None      None
# 376226  Inan  ...  Gen   None    Fem  None   Sing   None  None      None
# 410746  Inan  ...  Nom   None   Masc  None   Plur   None  None      None
# 512564  Anim  ...  Nom   None   Masc  None   Plur   None  None      None
#
#        voice stopword
# id
# 46256   None    False
# 103925  None    False
# 119604  None    False
# 175707  None    False
# 180260  None    False
# 318705  None    False
# 376226  None    False
# 410746  None    False
# 512564  None    False
#
# [9 rows x 21 columns]

# %%
child_window_array[7025:7030]
# Out:
# [(7025, ['огонь', 'жить', 'сердце', 'сказать', 'бог', 'слово', 'слово']),
#  (7026, ['жить', 'сердце', 'сказать', 'бог', 'слово', 'слово', 'дух']),
#  (7027, ['сердце', 'сказать', 'бог', 'слово', 'слово', 'дух', 'разум']),
#  (7028, ['сказать', 'бог', 'слово', 'слово', 'дух', 'разум', 'сказать']),
#  (7029, ['бог', 'слово', 'слово', 'дух', 'разум', 'сказать', 'павел'])]

# %%
parent_window_array[52840:52850]
# Out:
# [(52840,
#   ['день', 'спросить', 'сказать', 'рассудить', 'поступь', 'слово', 'сказать']),
#  (52841,
#   ['спросить',
#    'сказать',
#    'рассудить',
#    'поступь',
#    'слово',
#    'сказать',
#    'место']),
#  (52842,
#   ['сказать', 'рассудить', 'поступь', 'слово', 'сказать', 'место', 'избрать']),
#  (52843,
#   ['рассудить', 'поступь', 'слово', 'сказать', 'место', 'избрать', 'господь']),
#  (52844,
#   ['поступь', 'слово', 'сказать', 'место', 'избрать', 'господь', 'бог']),
#  (52845,
#   ['слово', 'сказать', 'место', 'избрать', 'господь', 'бог', 'призывать']),
#  (52846,
#   ['сказать', 'место', 'избрать', 'господь', 'бог', 'призывать', 'имя']),
#  (52847, ['место', 'избрать', 'господь', 'бог', 'призывать', 'имя', 'он']),
#  (52848,
#   ['избрать', 'господь', 'бог', 'призывать', 'имя', 'он', 'постараться']),
#  (52849,
#   ['господь', 'бог', 'призывать', 'имя', 'он', 'постараться', 'исполнить'])]

# %%
pd.DataFrame(child_window_array[7028][1])
# Out:
#          0
# 0  сказать
# 1      бог
# 2    слово
# 3    слово
# 4      дух
# 5    разум
# 6  сказать

# %%
pd.DataFrame.from_dict({x:y for x,y in parent_window_array[:5]})
# Out:
#            0          1          2          3          4
# 0     начало  сотворить        бог       небо      земля
# 1  сотворить        бог       небо      земля      земля
# 2        бог       небо      земля      земля  безвидный
# 3       небо      земля      земля  безвидный     пустой
# 4      земля      земля  безвидный     пустой       тьма
# 5      земля  безвидный     пустой       тьма     бездна
# 6  безвидный     пустой       тьма     бездна        дух

# %%
sorted_consec_sim_tuples = sorted(total_consec_sim_tuples.items(), key=lambda x:x[1], reverse=True)

# %%
sorted_consec_sim_tuples

# %%
compareDf = pd.DataFrame()
for x,y in sim_tuples[9:16]:
    #print(child_window_array[x[0]][0])
    #print(child_window_array[x[0]][1])
    compareDf[child_window_array[x[0]][0]] = child_window_array[x[0]][1]
    compareDf[parent_window_array[x[1]][0]] = parent_window_array[x[1]][1]
    #compareDf[x[1]] = parent_window_array[x][1]

compareDf

# %%
with open('./proc/sim_tuples.pkl', 'wb') as file:
    pickle.dump(sorted_sim_tuples, file)

# %%
with open('./proc/consec_sim_tuples.pkl', 'wb') as file:
    pickle.dump(sorted_consec_sim_tuples, file)

# %%
with open('./proc/sim_tuples.pkl', 'rb') as file:
    # The protocol version used is detected automatically, so we do not have to specify it.
    sim_tuples = pickle.load(file)

# %%
with open('./proc/consec_sim_tuples.pkl', 'rb') as file:
    # The protocol version used is detected automatically, so we do not have to specify it.
    csim_tuples = pickle.load(file)

# %%
csim_tuples

# %%
sim_tuples

# %%
pd.DataFrame(sim_tuples)

# %% [markdown]
# How do Gor'kii's *Mother* and the Synodal Bible overlap?
# windows of 3-5 words with 1-2+ of overlap
